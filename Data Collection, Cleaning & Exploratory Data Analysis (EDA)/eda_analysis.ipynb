# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_dataset.csv")
df.head()
# Out:
#      Area_SqFt  Rooms  Build_Year Location       Street_Type      Furnishing  \
# 0  2473.192784    4.0        1992   Jaipur  Residential Lane       Furnished
# 1  2353.472711    4.0        2006   Indore       Corner Plot     Unfurnished
# 2  2212.222005    3.0        2012   Jaipur    Highway Facing  Semi-Furnished
# 3  2823.886596    6.0        1993  Lucknow         Main Road     Unfurnished
# 4  1869.648721    5.0        2012   Jaipur       Corner Plot  Semi-Furnished
#
#   Property_Type Has_Pool     Price
# 0     Apartment       No  568486.0
# 1     Apartment      Yes  577214.0
# 2        Duplex       No  581300.0
# 3         Villa      Yes  794614.0
# 4     Apartment       No  493086.0

# %%
print("Dataset Shape: ", df.shape)
# Out:
# Dataset Shape:  (1124, 9)

# %%
print("Columns:")
print(df.columns)
# Out:
# Columns:
# Index(['Area_SqFt', 'Rooms', 'Build_Year', 'Location', 'Street_Type',
#        'Furnishing', 'Property_Type', 'Has_Pool', 'Price'],
#       dtype='object')

# %%
print("Data Types: ")
print(df.dtypes)
# Out:
# Data Types:
# Area_SqFt        float64
# Rooms            float64
# Build_Year         int64
# Location          object
# Street_Type       object
# Furnishing        object
# Property_Type     object
# Has_Pool          object
# Price            float64
# dtype: object

# %% [markdown]
# # Identify and Handle Missing values

# %%
print(df.isnull().sum())
# Out:
# Area_SqFt        33
# Rooms            33
# Build_Year        0
# Location          0
# Street_Type       0
# Furnishing       33
# Property_Type     0
# Has_Pool          0
# Price             0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.dropna(axis=1)

# %%
print(df.isnull().sum())
# Out:
# Area_SqFt        0
# Rooms            0
# Build_Year       0
# Location         0
# Street_Type      0
# Furnishing       0
# Property_Type    0
# Has_Pool         0
# Price            0
# dtype: int64

# %% [markdown]
# # Identify and Handle Duplicate rows

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Identify Incorrect data types

# %%
print(df.dtypes)
# Out:
# Area_SqFt        float64
# Rooms            float64
# Build_Year         int64
# Location          object
# Street_Type       object
# Furnishing        object
# Property_Type     object
# Has_Pool          object
# Price            float64
# dtype: object

# %%
df["Rooms"] = df["Rooms"].astype(int)

# %%
print(df.dtypes)
# Out:
# Area_SqFt        float64
# Rooms              int64
# Build_Year         int64
# Location          object
# Street_Type       object
# Furnishing        object
# Property_Type     object
# Has_Pool          object
# Price            float64
# dtype: object

# %% [markdown]
# # Performing EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#           Area_SqFt        Rooms   Build_Year         Price
# count   1027.000000  1027.000000  1027.000000  1.027000e+03
# mean    2238.749462     4.566699  2005.081792  6.098391e+05
# std      744.704478     1.676631    11.791113  1.450773e+05
# min      700.000000     2.000000  1985.000000  2.486400e+05
# 25%     1826.724874     3.000000  1995.000000  5.177645e+05
# 50%     2206.565229     5.000000  2005.000000  6.032640e+05
# 75%     2578.977535     6.000000  2015.000000  6.897460e+05
# max    10267.124330     7.000000  2024.000000  2.071402e+06

# %%
df.mean(numeric_only=True)
# Out:
# Area_SqFt       2238.749462
# Rooms              4.566699
# Build_Year      2005.081792
# Price         609839.064796
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Area_SqFt       2206.565229
# Rooms              5.000000
# Build_Year      2005.000000
# Price         603264.000000
# dtype: float64

# %%
df.mode()
# Out:
#    Area_SqFt  Rooms  Build_Year Location     Street_Type      Furnishing  \
# 0      700.0    4.0      2013.0    Noida  Highway Facing  Semi-Furnished
# 1        NaN    NaN         NaN      NaN             NaN             NaN
#
#   Property_Type Has_Pool     Price
# 0     Apartment       No  541348.0
# 1           NaN      NaN  631656.0

# %%
df.min(numeric_only=True)
# Out:
# Area_SqFt        700.0
# Rooms              2.0
# Build_Year      1985.0
# Price         248640.0
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Area_SqFt     1.026712e+04
# Rooms         7.000000e+00
# Build_Year    2.024000e+03
# Price         2.071402e+06
# dtype: float64

# %% [markdown]
# # Identifying Correlations

# %%
corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot = True, cmap = "coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Identify Trends Using Visualizations

# %% [markdown]
# # (a) Histograms

# %%
df.hist(figsize = (12,8))
plt.show()

# %% [markdown]
# # (b) Boxplot

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# # (c) Countplot

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x='Property_Type'
)

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # (d) Scatter Plot

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x='Area_SqFt',
    y='Price'
)

plt.show()

# %%
df.to_csv("cleaned_dataset.csv", index=False)

# %%
df.head()
# Out:
#      Area_SqFt  Rooms  Build_Year Location       Street_Type      Furnishing  \
# 0  2473.192784      4        1992   Jaipur  Residential Lane       Furnished
# 1  2353.472711      4        2006   Indore       Corner Plot     Unfurnished
# 2  2212.222005      3        2012   Jaipur    Highway Facing  Semi-Furnished
# 3  2823.886596      6        1993  Lucknow         Main Road     Unfurnished
# 4  1869.648721      5        2012   Jaipur       Corner Plot  Semi-Furnished
#
#   Property_Type Has_Pool     Price
# 0     Apartment       No  568486.0
# 1     Apartment      Yes  577214.0
# 2        Duplex       No  581300.0
# 3         Villa      Yes  794614.0
# 4     Apartment       No  493086.0
